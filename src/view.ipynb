# %%
from data_preprocessing import generate_synthetic_data

# %%
df = generate_synthetic_data()

df
# Out:
#       user_id  monthly_income  transaction_frequency  avg_loan_size  \
# 0           1           12056                     20          46426
# 1           2            7254                      9          60890
# 2           3           13604                     13          11597
# 3           4           27403                     10          12260
# 4           5            6718                     15          19965
# ...       ...             ...                    ...            ...
# 1195     1196           11526                      7          21875
# 1196     1197            7976                     14           6755
# 1197     1198           12606                     10          10056
# 1198     1199            9692                     14          35229
# 1199     1200           24132                     11          33612
#
#       savings_rate  digital_literacy_score  chatbot_sessions  \
# 0         0.021982               64.797451                 4
# ...
